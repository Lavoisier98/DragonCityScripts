# %%
import pyautogui as pg
import time as tm
import random as rd
import pyperclip as pc


#Pré-set: Um espaço livre no kindergarden e um na Hatchery
#Últimos travamentos:
#1) após 324 hatchings, 54 minutos
#2) após 311 hatchings, 51 minutos
#3) após 321 hatchings, 53 minutos
#4) após 322 hatchings, 52 minutos
#5) após 316 hatchings, 51 minutos
#6) após 225 hatchings, 36 minutos

wayStart = r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs"
wayEnd = r".png"
tela = pg.size()

pausas = ["23:59"]

def returnerToGame(Version):
    #Version = 1: Passa pelo StepVerification (Para ser usado como seerro)
    #Version = 2: Não passa pelo StepVerification (Para ser usado unicamente para reabrir o jogo)
    
    wayConcat1 = wayStart + r"\AdType1" + wayEnd
    wayConcat2 = wayStart + r"\AdType2" + wayEnd
    wayConcat3 = wayStart + r"\AdType3" + wayEnd
    wayConcat4 = wayStart + r"\AddError" + wayEnd
    wayConcat5 = wayStart + r"\Quests" + wayEnd
    wayConcat6 = wayStart + r"\QuestsEntrance" + wayEnd
    wayConcat6b = wayStart + r"\QuestsEntrance2" + wayEnd
    wayConcat7 = wayStart + r"\BattleIcon" + wayEnd
    wayConcat8 = wayStart + r"\CloseBreed" + wayEnd
    wayConcat9 = wayStart + r"\DC_Icon" + wayEnd
    wayConcat10 = wayStart + r"\AdType4" + wayEnd
    wayConcat11 = wayStart + r"\AdType5" + wayEnd
    wayConcat12 = wayStart + r"\MidnightPrize1" + wayEnd
    wayConcat13 = wayStart + r"\MidnightPrize2" + wayEnd
    wayConcat14 = wayStart + r"\MidnightPrize3" + wayEnd
    wayConcat15 = wayStart + r"\AdType6" + wayEnd
    wayConcat16 = wayStart + r"\AdType7" + wayEnd
    wayConcat17 = wayStart + r"\AdType8" + wayEnd
    StepVerificationReturn = None

    #Começa aqui

    def StepVerification(Version):
        print("Inicializando novo StepVerification...")
        wayConcat0 = wayConcat5
        detalhamento = 0.8
        NewAttempt = 0
        x = None
        while x == None and wayConcat0 != None:
            while x == None and NewAttempt < 6:
                x = pg.locateOnScreen(wayConcat0, grayscale=True, confidence=detalhamento)
                if x == None:
                    NewAttempt += 1
            if x == None:
                NewAttempt = 0
                #print(wayConcat0+" não encontrado")
                if wayConcat0 == wayConcat5:
                    wayConcat0 = wayConcat6
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat6:
                    wayConcat0 = wayConcat6b
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat6b:
                    wayConcat0 = wayConcat7
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat7:
                    wayConcat0 = wayConcat8
                    detalhamento = 0.73
                elif wayConcat0 == wayConcat8:
                    wayConcat0 = wayConcat1
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat1:
                    wayConcat0 = wayConcat2
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat2:
                    wayConcat0 = wayConcat3
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat3:
                    wayConcat0 = wayConcat4
                    detalhamento = 0.8
                elif wayConcat0 == wayConcat4:
                    wayConcat0 = wayConcat10
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat10:
                    wayConcat0 = wayConcat9
                    detalhamento = 0.96
                elif wayConcat0 == wayConcat9:
                    wayConcat0 = None
        if wayConcat0 != None:
            print(str(wayConcat0)+" encontrado! StepVerification finalizado e prosseguindo com script...")
        StepVerificationReturn = wayConcat0
        return StepVerificationReturn
    #63
    x3 = None
    while x3 == None:
        if Version == 1:
            wayConcat0 = StepVerification(1)
        elif Version == 2:
            wayConcat0 = None

        if wayConcat0 != None:
            print("Novo checkpoint em "+str(wayConcat0))
        else:
            print("Janela de jogo não encontrada. Reabrindo Dragon City...")
        if wayConcat0 == None: #Hipótese do jogo fechado
            print("Reabrindo jogo...")
            pc.copy('Dragon City')
            pg.press('win')
            tm.sleep(0.5)
            pg.hotkey('Ctrl','v')
            tm.sleep(0.5)
            pg.press('enter')
            tm.sleep(0.5)
            print("Aguardando carregamento...")

        if wayConcat0 == wayConcat9: #Hipótese do jogo minimizado
            x = pg.locateOnScreen(wayConcat0, grayscale=True, confidence=0.96)
            if x == None:
                while x == None:
                    x = pg.locateOnScreen(wayConcat0, grayscale=True, confidence=0.96)
            print("Reanalizando jogo minimizado...")
            pg.click(x)
            tm.sleep(0.6)
            wayConcat0 = StepVerification(1)
            print("Novo checkpoint em "+wayConcat0)

        if wayConcat0 == None or wayConcat0 == wayConcat1 or wayConcat0 == wayConcat2 or wayConcat0 == wayConcat3 or wayConcat0 == wayConcat4 or wayConcat0 == wayConcat8 or wayConcat0 == wayConcat10: #Hipótese do jogo nos anúncios
            print("Fechando anúncios obstrutores...")
            WithoutAd = 0
            FirstAd = False
            while WithoutAd < 10 or FirstAd == False:
                x = None
                while x == None and (WithoutAd < 10 or FirstAd == False):
                    x = pg.locateOnScreen(wayConcat1, grayscale=True, confidence=0.98)
                    #print("Printando While: ")
                    if x == None:
                        x = pg.locateOnScreen(wayConcat2, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                        if x == None:
                            x = pg.locateOnScreen(wayConcat3, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                            if x == None:
                                x = pg.locateOnScreen(wayConcat4, grayscale=True, confidence=0.81, region=(int(1*tela.width/2),0,int(1*tela.width/2)-1,int(tela.height/2.4)-1))
                                if x == None:
                                    x = pg.locateOnScreen(wayConcat10, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                                    if x == None:
                                        x = pg.locateOnScreen(wayConcat11, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                                        if x == None:
                                            x = pg.locateOnScreen(wayConcat14, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                            if x == None:
                                                x = pg.locateOnScreen(wayConcat15, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                                if x == None:
                                                    x = pg.locateOnScreen(wayConcat16, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                                    if x == None:
                                                        x = pg.locateOnScreen(wayConcat17, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                                        if x == None:
                                                            if tm.localtime()[3] == 0 and tm.localtime()[4] < 12:
                                                                while x == None:
                                                                    x = pg.locateOnScreen(wayConcat12, grayscale=True, confidence=0.73)
                                                                pg.moveTo(x)
                                                                pg.click(x)
                                                                tm.sleep(2.5)
                                                                x = None
                                                                z = None
                                                                y = 0
                                                                while x == None and y < 6:
                                                                    x = pg.locateOnScreen(wayConcat13, grayscale=True, confidence=0.73)
                                                                    if x == None:
                                                                        z = pg.locateOnScreen(wayConcat12, grayscale=True, confidence=0.73)
                                                                        if z != None:
                                                                            pg.moveTo(z)
                                                                            pg.click(z)
                                                                            y = 0
                                                                        else:
                                                                            y += 1
                                                                if y < 6:
                                                                    pg.moveTo(x)
                                                                    pg.click(x)
                                                                    x = None
                                                                    z = None
                                                                    while x == None:
                                                                        x = pg.locateOnScreen(wayConcat14, grayscale=True, confidence=0.73)
                                                                        if x == None:
                                                                            z = pg.locateOnScreen(wayConcat13, grayscale=True, confidence=0.73)
                                                                            if z == None:
                                                                                z = pg.locateOnScreen(wayConcat12, grayscale=True, confidence=0.73)
                                                                            if z != None:
                                                                                pg.moveTo(z)
                                                                                pg.click(z)
                                                                    pg.moveTo(x)
                                                                    pg.click(x)
                                                                WithoutAd = 0
                                                            WithoutAd += 1
                                                    
                    if x != None:
                        print("Fechando anúncios agora...")
                        WithoutAd = 0
                        FirstAd = True
                        pg.click(x)
                    else:
                        #x = pg.locateOnScreen(wayConcat7, grayscale=True, confidence=0.85, region=(0,int(2*tela.height/3),int(0.4*tela.width/3)-1,int(tela.height/3)))
                        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BattleIcon.png", grayscale=True, confidence=0.8)
                        if x != None and FirstAd == False:
                            pg.moveTo(x)
                            pg.click(x)
                            #FirstAd = True
                            x = None
                        else:
                            print("Anúncios não localizados...")
            print("Anúncios fechados! Prosseguindo com carregamento...")
            x3 = 1
    tm.sleep(0.2)
    pg.moveTo(int(0.85*tela.width),int(0.15*tela.height))
    tm.sleep(0.1)
    pg.dragTo(int(0.75*tela.width),int(0.25*tela.height), 0.2, button='left')
    tm.sleep(0.5)
    #pg.scroll(-120)
                    #print("Loop Interno: "+str(WithoutAd)+"     1° Ad clicado? "+str(FirstAd)+"     Click: "+str(x))


tm.sleep(4)
#pg.PAUSE = 0.185
k = 0
success = 0
#235,256
randomStop = rd.randint(215,226)
now = tm.localtime()
iTime = 86400 * now[7] + 3600 * now[3] + 60 * now[4] + now[5]
print("Starting at "+str(now[3])+":"+str(now[4])+":"+str(now[5])+". Security break after "+str(randomStop)+" hatchings...")
while True: #k < 100000:
    x = None
    x2 = None
    while x == None and x2 == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\GetNew.png", grayscale=True, confidence=0.8)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", grayscale=True, confidence=0.8)
    verify = False
    while verify == False:
        x3 = None
        if x == None:
            pg.moveTo(x2)
            pg.click(x2)
            tm.sleep(0.4)
            while x == None and x3 == None:
                x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\GetNew.png", grayscale=True, confidence=0.8)
                if x == None:
                    x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.8)
                    if x3 == None:
                        x7 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Erro3.png", confidence=0.8)
                        if x7 != None:
                            x8 = None
                            while x8 == None:
                                x8 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", confidence=0.8)
                            pg.moveTo(x8)
                            pg.click(x8)
                        else:
                            x7 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool2.png", confidence=0.75)
                            if x7 != None:
                                pg.moveTo(x7)
                                pg.click(x7)
                            else:
                                x7 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", confidence=0.71)
                                if x7 != None:
                                    pg.moveTo(x7)
                                    pg.click(x7)
                                
        if x != None:
            tm.sleep(0.45)
            pg.moveTo(x)
            pg.click(x)
            x = None
            while x == None and x3 == None:
                x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Gold.png", grayscale=True, confidence=0.8)
                if x == None:
                    x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.8)
                    if x3 == None:
                        x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\GetNew.png", confidence=0.75)
                        if x4 != None:
                            pg.moveTo(x4)
                            pg.click(x4)
                            
            if x != None:
                pg.moveTo(x)
                pg.click(x)
                verify = True
            elif x3 != None:
                pg.moveTo(x3)
                pg.click(x3)                
#40
        elif x3 != None:
        
        
            pg.moveTo(x3)
            pg.click(x3)
    tm.sleep(0.6)
    x = None
    x4 = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\TerraDragon2.png", grayscale=True, confidence=0.8)
        if x == None:
            x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Erro2.png", grayscale=True, confidence=0.85)
            if x4 != None:
                x2 = pg.center(x)
                xReturn = x.left - x.width / 0.42
                yReturn = x2.y - x.height * 2.6
                pg.moveTo(xReturn, yReturn)
                pg.moveTo(xReturn, yReturn)
                
    verify = False
    while verify == False:
        x2 = pg.center(x)
        xTerraDragon = x.left + x.width / 2
        yTerraDragon = x2.y + x.height / 2
        pg.moveTo(xTerraDragon, yTerraDragon)
        pg.click(xTerraDragon, yTerraDragon)
        tm.sleep(0.56)
        x = None
        y = None
        z = None
        while x == None and y == None:
            y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg3.png", grayscale=True, confidence=0.87)
#70
            if y == None:
                x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\TerraDragon2.png", grayscale=True, confidence=0.8)
                if x == None and y == None:
                    z = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.8)
                    if z != None:
                        pg.moveTo(z)
                        pg.click(z)
                    else:
                        z2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Erro2.png", confidence=0.8)
                        if z2 != None:
                            pg.moveTo(z2)
                            pg.click(z2)
                        else:
                            x6 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Earth.png", grayscale=True, confidence=0.85)
                            if x6 != None:
                                x5 = None
                                while x5 == None:
                                    x5 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\HatcheryLight.png", grayscale=True, confidence=0.85)
                                if x5 != None:
                                    pg.moveTo(x5)
                                    pg.click(x5)
                                    while z == None:
                                        z = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.8)
                                    pg.moveTo(z)
                                    pg.click(z)
                                else:
                                    x7 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Erro3.png", confidence=0.8)
                                    if x7 != None:
                                        x8 = None
                                        while x8 == None:
                                            x8 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", confidence=0.8)
                                        pg.moveTo(x8)
                                        pg.click(x8)                                    
        if y != None:
            verify = True
    pg.moveTo(y)
    pg.click(y)

    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\PlaceReady.png", grayscale=True, confidence=0.8)
        if x == None:
            y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg3.png", grayscale=True, confidence=0.87)
            if y != None:
                pg.moveTo(y)
                pg.click(y)
            else:
                y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", grayscale=True, confidence=0.8)
                if y != None:
                    pg.moveTo(y)
                    pg.click(y)
                    tm.sleep(0.35)
                    y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
                    if y != None:
                        pg.moveTo(y)
                        pg.click(y)
                
    pg.moveTo(x)
    pg.click(x)
    tm.sleep(0.1)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Arrow1.png", confidence=0.85)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\PlaceReady.png", confidence=0.75)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
    verify = False
    while verify == False: 
        x2 = pg.center(x)
        xKindergarden = x.left + x.width / 2
        yKindergarden = x2.y + x.height * 1.4
        pg.moveTo(xKindergarden, yKindergarden)
        pg.click(xKindergarden, yKindergarden)
        tm.sleep(0.65)
        x = None
#100
        y = None
        while x == None and y == None:
            y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Earth.png", grayscale=True, confidence=0.85)    
            if y == None:
                x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Arrow1.png", confidence=0.85)
        if y != None:
            verify = True
    pg.moveTo(y)
    pg.click(y)
    tm.sleep(0.2)
    x = None
    conf = 0.85
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCoolC.png", confidence=0.85)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\EventEnjoy.png", confidence=0.75)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
                tm.sleep(2)
                x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.75)
                if x2 != None:
                    pg.moveTo(x2)
                    pg.click(x2)
            else:
                x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Earth.png", confidence=0.75)
                if x2 != None:
                    pg.moveTo(x2)
                    pg.click(x2)
        if x == None:
            conf -= 0.01
    pg.moveTo(x)
    pg.click(x)
    tm.sleep(0.2)
    x = None
    x2 = None
    conf = 0.85
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool2.png", confidence=conf)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCoolC.png", confidence=conf)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                conf -= 0.01
    pg.moveTo(x)
    pg.click(x)
    k += 1
    success += 1
    fTime = 86400 * tm.localtime()[7] + 3600 * tm.localtime()[3] + 60 * tm.localtime()[4] + tm.localtime()[5]
    print(r"Hatching N°"+str(success)+" concluded at "+str(tm.localtime()[3])+":"+str(tm.localtime()[4])+":"+str(tm.localtime()[5])+", during "+str(int((fTime-iTime)/3600))+" hours, "+str(int((fTime-iTime)/60)-int((fTime-iTime)/3600)*60)+" minutes and "+str(int(fTime-iTime)-int((fTime-iTime)/60)*60)+" seconds. More "+str(success*5)+" for the guild!")
    tm.sleep(0.8)
    #Pausa opcional de tempo às 23:59 e às 08:02, durante 20 minutos
    for pausaIndividual in pausas:
        if tm.localtime()[3] == int(pausaIndividual[:2]) and tm.localtime()[4] == int(pausaIndividual[3:]):
            duration = 25 #duração em minutos
            for _ in range(duration*15):
                tm.sleep(2)
                pg.moveTo(rd.randint(0,tela.width),rd.randint(0,tela.height),2)
            k = randomStop
            print("Scheduled %d minutes pause concluded. Restarting DC..."%(duration))
    if k == randomStop:
        #randomTime = rd.randint(180,190)
        print("Stopping again for security break after "+str(randomStop)+" hatchings...")
        tm.sleep(13.5)
        pg.hotkey('alt','f4')
        tm.sleep(0.5)
        returnerToGame(2)
        tm.sleep(2.5)
        #tm.sleep(randomTime)
        randomStop = rd.randint(215,226)
        k = 0
# Out:
# Starting at 21:3:13. Security break after 222 hatchings...
# Hatching N°1 concluded at 21:3:23, during 0 hours, 0 minutes and 10 seconds. More 5 for the guild!
# Hatching N°2 concluded at 21:3:32, during 0 hours, 0 minutes and 19 seconds. More 10 for the guild!
# Hatching N°3 concluded at 21:3:42, during 0 hours, 0 minutes and 29 seconds. More 15 for the guild!
# Hatching N°4 concluded at 21:3:52, during 0 hours, 0 minutes and 39 seconds. More 20 for the guild!
# Hatching N°5 concluded at 21:4:2, during 0 hours, 0 minutes and 49 seconds. More 25 for the guild!
# Hatching N°6 concluded at 21:4:11, during 0 hours, 0 minutes and 58 seconds. More 30 for the guild!
# Hatching N°7 concluded at 21:4:21, during 0 hours, 1 minutes and 8 seconds. More 35 for the guild!
# Hatching N°8 concluded at 21:4:31, during 0 hours, 1 minutes and 18 seconds. More 40 for the guild!
# Hatching N°9 concluded at 21:4:41, during 0 hours, 1 minutes and 28 seconds. More 45 for the guild!
# ...

# %%
#testador de accurancy da imagem. Retorna o valor máximo de confidence
tm.sleep(2)
y = 0.93
x = None
while x == None:
    x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\GetNew.png", grayscale=True, confidence=y)
    if x == None:
        y-= 0.02
pg.moveTo(x)
print(y)
#x2 = pg.center(x)
#xTerraDragon = x.left + x.width / 2
#yTerraDragon = x2.y + x.height / 2
#pg.moveTo(xTerraDragon, yTerraDragon)
k += 1
# Out:
# 0.93

# %%
import random as rd

print(tm.localtime())
x = tm.localtime()[5]
y = tm.localtime()[5]
print(str(tm.localtime()[3])+":"+str(tm.localtime()[4])+":"+str(tm.localtime()[5]))
print(86400 * tm.localtime()[7] + 3600 * tm.localtime()[3] + 60 * tm.localtime()[4] + tm.localtime()[5])
tm.sleep(20)
print(86400 * tm.localtime()[7] + 3600 * tm.localtime()[3] + 60 * tm.localtime()[4] + tm.localtime()[5])
# Out:
# time.struct_time(tm_year=2023, tm_mon=10, tm_mday=13, tm_hour=14, tm_min=50, tm_sec=1, tm_wday=4, tm_yday=286, tm_isdst=0)
# 14:50:1
# 24763801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 8>()
#       6 print(str(tm.localtime()[3])+":"+str(tm.localtime()[4])+":"+str(tm.localtime()[5]))
#       7 print(86400 * tm.localtime()[7] + 3600 * tm.localtime()[3] + 60 * tm.localtime()[4] + tm.localtime()[5])
# ----> 8 tm.sleep(20)
#       9 print(86400 * tm.localtime()[7] + 3600 * tm.localtime()[3] + 60 * tm.localtime()[4] + tm.localtime()[5])
#
# KeyboardInterrupt:

# %%
import math as mt, pyautogui as pg, random as rd, keyboard as kb


#print((mt.asin(mt.pow(3,0.5)/3))*180/mt.pi)
print(pg.size())
tela = pg.size()
for _ in range(5):
    duration = 16
    tm.sleep(2)
    pg.moveTo(rd.randint(5,tela.width-5),rd.randint(5,tela.height-5),2)
print("Scheduled %d minutes pause concluded. Restarting DC..."%(duration))
# Out:
# Size(width=1360, height=768)
# Scheduled 16 minutes pause concluded. Restarting DC...

# %%
import keyboard as kb

tm.sleep(1)
while True:
    if kb.is_pressed("a"):
        print(kb.is_pressed("a"))
        break
print(kb.read_key()+"aaa")
#read_key não serve para None
while True:
    if kb.read_key() == "a":
        print(kb.read_key())
        break
    tm.sleep(1)
print("chegou aqui")
kb.wait("c")

# %%
import time as tm

if tm.localtime()[8] == 0:
    print(tm.localtime()[3])
# Out:
# 21

# %%
tm.sleep(3)
conf = 0.99
x = None
while x == None:
    #x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BattleIcon.png", grayscale=True, confidence=conf, region=(0,int(2*tela.height/3),int(0.4*tela.width/3)-1,int(tela.height/3)))
    x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BattleIcon.png", grayscale=True, confidence=0.8)
    if x == None:
        print("Imagem não encontrada")
        conf -= 0.01
pg.moveTo(x)
pg.click(x)
