# %%
import pyautogui as pg
import pyperclip as pc
import time as tm

tm.sleep(5)
k = 0
while True: #k < 10000:
    #Vender dragons
    x = None
    verify = False
    while x == None and verify == False:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", grayscale=True, confidence=0.76)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.76)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            if x2 == None:
                verify = True
    pg.moveTo(x)
    pg.click(x)
    verify = False
    while verify == False:
        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.8)
            if x == None:
                x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", grayscale=True, confidence=0.8)
                if x2 != None:
                    pg.moveTo(x2)
                    pg.click(x2)
                else:
                    x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
                    if x3 != None:
                        pg.moveTo(x3)
                        pg.click(x3)
                    else:
                        x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool2.png", grayscale=True, confidence=0.76)
                        if x4 != None:
                            pg.moveTo(x4)
                            pg.click(x4)
        pg.moveTo(x)
        pg.click(x)
        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCoolB.png", grayscale=True, confidence=0.76)
            if x == None:
                x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", grayscale=True, confidence=0.76)
                if x2 == None:
                    tm.sleep(1)
                    x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.76)
                    if x3 != None:
                        pg.moveTo(x3)
                        pg.click(x3)
#50
                    else:
                        x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.76)
                        if x4 != None:
                            pg.moveTo(x4)
                            pg.click(x4)
                else:
                    pg.moveTo(x2)
                    pg.click(x2)
                    x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.76)
                    if x3 != None:
                        tm.sleep(0.5)
                        pg.moveTo(x3)
                        pg.click(x3)
        pg.moveTo(x)
        pg.click(x)    
        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool2.png", grayscale=True, confidence=0.76)
            if x == None:
                x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCoolB.png", grayscale=True, confidence=0.76)
                if x2 != None:
                    pg.moveTo(x2)
                    pg.click(x2)
        pg.moveTo(x)
        pg.click(x)
        tm.sleep(0.4)
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.76)
        if x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.76)
            if x == None:
                x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.76)
                if x == None:
                    verify = True

    #Pegar procriações prontas
    pg.hscroll(-120)
    x = None
    while x == None and x2 == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady2.png", grayscale=False, confidence=0.95)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady3.png", grayscale=False, confidence=0.95)
    if x != None:
        pg.moveTo(x)
        pg.click(x)
    else:
        pg.moveTo(x2)
        pg.click(x2)
    tm.sleep(0.3)
    while x != None or x2 != None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady2.png", grayscale=False, confidence=0.95)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady3.png", grayscale=False, confidence=0.95)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
        pg.moveTo(x)
#100
        pg.click(x)
    
    #Criar novas procriações na 1
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave1.png", grayscale=True, confidence=0.85)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady2.png", grayscale=False, confidence=0.95)
                if x3 != None:
                    pg.moveTo(x3)
                    pg.click(x3)
                else:
                    x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady3.png", grayscale=False, confidence=0.95)
                    if x4 != None:
                        pg.moveTo(x4)
                        pg.click(x4)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Rebreed.png", grayscale=True, confidence=0.9)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave1.png", grayscale=True, confidence=0.85)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
                if x3 != None:
                    pg.moveTo(x3)
                    pg.click(x3)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Breed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    
    #Criar novas procriações na 2
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave2.png", grayscale=True, confidence=0.85)
        #x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave3.png", grayscale=True, confidence=0.85)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                tm.sleep(0.5)
                x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady2.png", grayscale=True, confidence=0.9)
                x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady3.png", grayscale=True, confidence=0.9)
                if x3 != None or x4 != None:
                    if x3 != None:
                        pg.moveTo(x3)
                        pg.click(x3)
                    else:
                        pg.moveTo(x4)
                        pg.click(x4)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Rebreed.png", grayscale=True, confidence=0.9)
        if x == None:
#150
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave2.png", grayscale=True, confidence=0.85)
            #x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave3.png", grayscale=True, confidence=0.85)            
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Breed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    tm.sleep(0.4)
    pg.hscroll(120)
    k += 1
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Input In [22], in <cell line: 9>()
#      51                     x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.76)
#      52                     if x3 != None:
# ---> 53                         pg.moveTo(x3)
#      54                         pg.click(x3)
#      55 #50
#      56                     else:
#
# File C:\Program Files\Python\lib\site-packages\pyautogui\__init__.py:597, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     595 @functools.wraps(wrappedFunction)
#     596 def wrapper(*args, **kwargs):
# --> 597     failSafeCheck()
#     598     returnVal = wrappedFunction(*args, **kwargs)
#     599     _handlePause(kwargs.get("_pause", True))
#
# File C:\Program Files\Python\lib\site-packages\pyautogui\__init__.py:1722, in failSafeCheck()
# ...

# %%
tm.sleep(4)
pg.moveTo(x=762, y=524)

for ready in pg.locateAllOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.99):
    pg.moveTo(ready)
    pg.click(ready)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool.png", grayscale=True, confidence=0.76)
    pg.moveTo(x)
    pg.click(x)    
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool2.png", grayscale=True, confidence=0.76)
    pg.moveTo(x)
    pg.click(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 tm.sleep(4)
#       2 pg.moveTo(x=762, y=524)
#       4 for ready in pg.locateAllOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.99):
#
# KeyboardInterrupt:

# %%
tm.sleep(4)
pg.moveTo(x=1065, y=653)
print("Deu certo")
# Out:
# Deu certo

# %%
tm.sleep(4)
x = None
while x == None:
    x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Rebreed.png", grayscale=True, confidence=0.9)
pg.moveTo(x)
pg.click(x)
x = None
while x == None:
    x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Breed.png", grayscale=True, confidence=0.9)
pg.moveTo(x)
pg.click(x)
x = None
while x == None:
    x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", grayscale=True, confidence=0.9)
pg.moveTo(x)
pg.click(x)

# %%
tm.sleep(4)
x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCoolB.png", grayscale=True, confidence=0.76)
pg.moveTo(x)
print(x)
# Out:
# Box(left=851, top=499, width=148, height=49)

# %%
import cv2
import pytesseract
import pyautogui as pg
import time as tm

tela = pg.size()
y = "HeroicRunFight5"
z = pg.screenshot(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AutoScreenshoot.png",region=(0,int(2*tela.height/3),tela.width-1,int(tela.height/3)-1))
#x = cv2.imread(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\HeroicRunFight5.png")
#pytesseract.pytesseract.tesseract_cmd = r"C:\Users\user\Desktop\Felipe\Jupyter\Tesseract\Tesseract.exe"
#configur = r'--oem 3 --psm 7'
#x2 = pytesseract.image_to_string(x,config=configur)
#print(x2)
