# %%
import pyautogui as pg
import pyperclip as pc
import time as tm

tm.sleep(5)
k = 0
while True: #k < 10000:
    k2 = 0
    while k2 < 2:
        x = None
        verify = False
        while x == None or verify == False:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Hatchery.png", grayscale=True, confidence=0.76)
            if x == None:
                x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.76)
                if x2 != None:
                    pg.moveTo(x2)
                    pg.click(x2)
                if x2 == None:
                    verify = True
        pg.moveTo(x)
        pg.click(x)
        x = None
        y = None
        z = None
        while x == None and y == None:
            y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.8)
    #70
            if x == None and y == None:
                z = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.8)
                if z != None:
                    pg.moveTo(z)
                    pg.click(z)
                else:
                    z2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Erro2.png", confidence=0.8)
                    if z2 != None:
                        pg.moveTo(z2)
                        pg.click(z2)
                    else:
                        x6 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Earth.png", grayscale=True, confidence=0.85)
                        if x6 != None:
                            x5 = None
                            while x5 == None:
                                x5 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\HatcheryLight.png", grayscale=True, confidence=0.85)
                            if x5 != None:
                                pg.moveTo(x5)
                                pg.click(x5)
                                while z == None:
                                    z = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", confidence=0.8)
                                pg.moveTo(z)
                                pg.click(z)
        if y != None:
            verify = True
        pg.moveTo(y)
        pg.click(y)

        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\PlaceReady.png", grayscale=True, confidence=0.8)
            if x == None:
                y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\ReadyEgg.png", grayscale=True, confidence=0.8)
                if y != None:
                    pg.moveTo(y)
                    pg.click(y)
        pg.moveTo(x)
        pg.click(x)
        tm.sleep(0.1)
        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Arrow1.png", confidence=0.85)   
        verify = False
        while verify == False: 
            x2 = pg.center(x)
            xKindergarden = x.left + x.width / 2
            yKindergarden = x2.y + x.height * 1.5
            pg.moveTo(xKindergarden, yKindergarden)
            pg.click(xKindergarden, yKindergarden)
            x = None
    #100
            y = None
            while x == None and y == None:
                y = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Earth.png", grayscale=True, confidence=0.85)    
                if y == None:
                    x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Arrow1.png", confidence=0.85)
            if y != None:
                verify = True
        pg.moveTo(y)
        pg.click(y)
        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool.png", confidence=0.85)   
        pg.moveTo(x)
        pg.click(x)
        x = None
        while x == None:
            x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\SellCool2.png", confidence=0.85)   
        pg.moveTo(x)
        pg.click(x)
        k2 += 1
    
    #Criar novas procriações na 1
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave1.png", grayscale=True, confidence=0.85)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady2.png", grayscale=False, confidence=0.95)
                if x3 != None:
                    pg.moveTo(x3)
                    pg.click(x3)
                else:
                    x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady3.png", grayscale=False, confidence=0.95)
                    if x4 != None:
                        pg.moveTo(x4)
                        pg.click(x4)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Rebreed.png", grayscale=True, confidence=0.9)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave1.png", grayscale=True, confidence=0.85)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
                if x3 != None:
                    pg.moveTo(x3)
                    pg.click(x3)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Breed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)

    #Criar novas procriações na 2
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave2.png", grayscale=True, confidence=0.85)
        if x == None:
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
            else:
                x3 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady2.png", grayscale=True, confidence=0.9)
                x4 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedReady3.png", grayscale=True, confidence=0.9)
                if x3 != None or x4 != None:
                    if x3 != None:
                        pg.moveTo(x3)
                        pg.click(x3)
                    else:
                        pg.moveTo(x4)
                        pg.click(x4)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Rebreed.png", grayscale=True, confidence=0.9)
        if x == None:
#150
            x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave2.png", grayscale=True, confidence=0.85)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\Breed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    x = None
    while x == None:
        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\CloseBreed.png", grayscale=True, confidence=0.9)
    pg.moveTo(x)
    pg.click(x)
    tm.sleep(0.4)
    pg.hscroll(120)
    k += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 8>()
#     102 x = None
#     103 while x == None:
# --> 104     x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BreedCave1.png", grayscale=True, confidence=0.85)
#     105     if x == None:
#     106         x2 = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\AddError.png", grayscale=True, confidence=0.8)
#
# File C:\Program Files\Python\lib\site-packages\pyautogui\__init__.py:175, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     172 @functools.wraps(wrappedFunction)
#     173 def wrapper(*args, **kwargs):
#     174     try:
# --> 175         return wrappedFunction(*args, **kwargs)
#     176     except pyscreeze.ImageNotFoundException:
#     177         raise ImageNotFoundException
#
# File C:\Program Files\Python\lib\site-packages\pyautogui\__init__.py:213, in locateOnScreen(*args, **kwargs)
#     211 @raisePyAutoGUIImageNotFoundException
#     212 def locateOnScreen(*args, **kwargs):
# --> 213     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyscreeze\__init__.py:373, in locateOnScreen(image, minSearchTime, **kwargs)
#     371 try:
#     372     screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 373     retVal = locate(image, screenshotIm, **kwargs)
#     374     try:
#     375         screenshotIm.fp.close()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyscreeze\__init__.py:353, in locate(needleImage, haystackImage, **kwargs)
#     351 # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     352 kwargs['limit'] = 1
# --> 353 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     354 if len(points) > 0:
#     355     return points[0]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyscreeze\__init__.py:229, in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     226     step = 1
#     228 # get all matches at once, credit: https://stackoverflow.com/questions/7670112/finding-a-subimage-inside-a-numpy-image/9253805#9253805
# --> 229 result = cv2.matchTemplate(haystackImage, needleImage, cv2.TM_CCOEFF_NORMED)
#     230 match_indices = numpy.arange(result.size)[(result > confidence).flatten()]
#     231 matches = numpy.unravel_index(match_indices[:limit], result.shape)
#
# KeyboardInterrupt:
