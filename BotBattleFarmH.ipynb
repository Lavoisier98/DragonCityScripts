# %%
import pyautogui as pg
import pyperclip as pc
import time as tm

#ATENÇÃO: DIGITE AQUI O NÚMERO CORRETO DE MISSÕES E KILLS ANTES DE RODAR O SCRIPT!
NumeroDeQuestsAntes =9
InitialKillNumber = 0

#ATENÇÃO: CERTIFIQUE-SE DE ESTAREM   OS DRAGÕES CERTOS ANTES DE RODAR O SCRIPT!
# ATENÇÃO: CERTIFIQUE-SE DE ESTAREM OS DRAGÕES CERTOS ANTES DE RODAR O SCRIPT!
#  ATENÇÃO: CERTIFIQUE-SE DE ESTAREM OS DRAGÕES CERTOS ANTES DE RODAR O SCRIPT!
# ATENÇÃO: CERTIFIQUE-SE DE ESTAREM OS DRAGÕES CERTOS ANTES DE RODAR O SCRIPT!
#ATENÇÃO: CERTIFIQUE-SE DE ESTAREM   OS DRAGÕES CERTOS ANTES DE RODAR O SCRIPT!

#ATENÇÃO: Arena ruim para elementos água, luz, elétrico, fogo e vento!

#Histórico de desligamentos:
# 1) 172 ciclos e duração de 01:20:00

#Expectativa por kill: 27 segundos
#Database fixa:


wayStart = r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs"
wayEnd = r".png"
sucessos = 0
fracassos = 0
fracassosSeguidos = 0
tm.localtime()
tela = pg.size()

def clickhold():
    x = None
    x2 = None
    while x == None:
        wayConcat1 = wayStart + r"\Quests" + wayEnd
        wayConcat2 = wayStart + r"\AddError" + wayEnd        
        x = pg.locateOnScreen(wayConcat1, grayscale=True, confidence=0.8)
        if x == None:
            x2 = pg.locateOnScreen(wayConcat2, grayscale=True, confidence=0.8)
            if x2 != None:
                pg.moveTo(x2)
                pg.click(x2)
    #print("print do clickhold")
    #print(x)
    x2 = pg.center(x)
    xReturn = x.left + x.width / 0.35
    #Alterar aqui quanto ao número de missions antes da última disponível
    xReturn2 = x.left - x.width / 0.8
    yReturn = x2.y + x.height * 2.6
    pg.moveTo(xReturn, yReturn)
    pg.moveTo(xReturn, yReturn)
    tm.sleep(0.1)
    #Mude aqui quando o número de missões mudar, no argumento 3 (segundos para movimentar, quanto menos, mais rápido)
    #pg.dragTo(xReturn2, yReturn, 0.601, button='left')
    #tm.sleep(5)
    pg.scroll(-1520*NumeroDeQuestsAntes)
    pg.moveTo(x)
    #tm.sleep(0.9)

def returnerToGame(Version):
    wayConcat1 = wayStart + r"\AdType1" + wayEnd
    wayConcat2 = wayStart + r"\AdType2" + wayEnd
    wayConcat3 = wayStart + r"\AdType3" + wayEnd
    wayConcat4 = wayStart + r"\AddError" + wayEnd
    wayConcat5 = wayStart + r"\Quests" + wayEnd
    wayConcat6 = wayStart + r"\QuestsEntrance" + wayEnd
    wayConcat6b = wayStart + r"\QuestsEntrance2" + wayEnd
    wayConcat7 = wayStart + r"\BattleIcon" + wayEnd
    wayConcat8 = wayStart + r"\CloseBreed" + wayEnd
    wayConcat9 = wayStart + r"\DC_Icon" + wayEnd
    wayConcat10 = wayStart + r"\AdType4" + wayEnd
    wayConcat11 = wayStart + r"\AdType5" + wayEnd
    wayConcat12 = wayStart + r"\AdType6" + wayEnd
    wayConcat13 = wayStart + r"\AdType7" + wayEnd
    wayConcat14 = wayStart + r"\MidnightPrize3" + wayEnd
    wayConcat15 = wayStart + r"\AdType6" + wayEnd
    wayConcat16 = wayStart + r"\AdType7" + wayEnd
    wayConcat17 = wayStart + r"\AdType8" + wayEnd
    StepVerificationReturn = None

    #Começa aqui

    def StepVerification(Version):
        print("Inicializando novo StepVerification...")
        wayConcat0 = wayConcat5
        detalhamento = 0.8
        NewAttempt = 0
        x = None
        while x == None and wayConcat0 != None:
            while x == None and NewAttempt < 6:
                x = pg.locateOnScreen(wayConcat0, grayscale=True, confidence=detalhamento)
                if x == None:
                    NewAttempt += 1
            if x == None:
                NewAttempt = 0
                #print(wayConcat0+" não encontrado")
                if wayConcat0 == wayConcat5:
                    wayConcat0 = wayConcat6
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat6:
                    wayConcat0 = wayConcat6b
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat6b:
                    wayConcat0 = wayConcat7
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat7:
                    wayConcat0 = wayConcat8
                    detalhamento = 0.73
                elif wayConcat0 == wayConcat8:
                    wayConcat0 = wayConcat1
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat1:
                    wayConcat0 = wayConcat2
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat2:
                    wayConcat0 = wayConcat3
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat3:
                    wayConcat0 = wayConcat4
                    detalhamento = 0.8
                elif wayConcat0 == wayConcat4:
                    wayConcat0 = wayConcat10
                    detalhamento = 0.98
                elif wayConcat0 == wayConcat10:
                    wayConcat0 = wayConcat9
                    detalhamento = 0.96
                elif wayConcat0 == wayConcat9:
                    wayConcat0 = None
        if wayConcat0 != None:
            print(str(wayConcat0)+" encontrado! StepVerification finalizado e prosseguindo com script...")
        StepVerificationReturn = wayConcat0
        return StepVerificationReturn
    #63
    x3 = None
    while x3 == None:
        if Version == 1:
            wayConcat0 = StepVerification(1)
        else:
            wayConcat0 = None
        if wayConcat0 != None:
            print("Novo checkpoint em "+str(wayConcat0))
        else:
            print("Janela de jogo não encontrada. Reabrindo Dragon City...")
        if wayConcat0 == None: #Hipótese do jogo fechado
            print("Reabrindo jogo...")
            pc.copy('Dragon City')
            pg.press('win')
            tm.sleep(0.8)
            pg.hotkey('Ctrl','v')
            pg.press('enter')
            tm.sleep(0.8)
            print("Aguardando carregamento...")

        if wayConcat0 == wayConcat9: #Hipótese do jogo minimizado
            x = pg.locateOnScreen(wayConcat0, grayscale=True, confidence=0.96)
            if x == None:
                while x == None:
                    x = pg.locateOnScreen(wayConcat0, grayscale=True, confidence=0.96)
            print("Reanalizando jogo minimizado...")
            pg.click(x)
            tm.sleep(0.6)
            wayConcat0 = StepVerification(1)
            print("Novo checkpoint em "+wayConcat0)

        if wayConcat0 == None or wayConcat0 == wayConcat1 or wayConcat0 == wayConcat2 or wayConcat0 == wayConcat3 or wayConcat0 == wayConcat4 or wayConcat0 == wayConcat8 or wayConcat0 == wayConcat10: #Hipótese do jogo nos anúncios
            print("Fechando anúncios obstrutores...")
            WithoutAd = 0
            FirstAd = False
            while WithoutAd < 10 or FirstAd == False:
                x = None
                while x == None and (WithoutAd < 10 or FirstAd == False):
                    x = pg.locateOnScreen(wayConcat1, grayscale=True, confidence=0.98)
                    #print("Printando While: ")
                    if x == None:
                        x = pg.locateOnScreen(wayConcat2, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                        if x == None:
                            x = pg.locateOnScreen(wayConcat3, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                            if x == None:
                                x = pg.locateOnScreen(wayConcat4, grayscale=True, confidence=0.81, region=(int(1*tela.width/2),0,int(1*tela.width/2)-1,int(tela.height/2.4)-1))
                                if x == None:
                                    x = pg.locateOnScreen(wayConcat10, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                                    if x == None:
                                        x = pg.locateOnScreen(wayConcat11, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
                                        if x == None:
                                            x = pg.locateOnScreen(wayConcat14, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                            if x == None:
                                                x = pg.locateOnScreen(wayConcat15, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                                if x == None:
                                                    x = pg.locateOnScreen(wayConcat16, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                                    if x == None:
                                                        x = pg.locateOnScreen(wayConcat17, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
                                                        if x == None:
                                                            if tm.localtime()[3] == 0 and tm.localtime()[4] < 12:
                                                                while x == None:
                                                                    x = pg.locateOnScreen(wayConcat12, grayscale=True, confidence=0.73)
                                                                pg.moveTo(x)
                                                                pg.click(x)
                                                                tm.sleep(2.5)
                                                                x = None
                                                                z = None
                                                                y = 0
                                                                while x == None and y < 6:
                                                                    x = pg.locateOnScreen(wayConcat13, grayscale=True, confidence=0.73)
                                                                    if x == None:
                                                                        z = pg.locateOnScreen(wayConcat12, grayscale=True, confidence=0.73)
                                                                        if z != None:
                                                                            pg.moveTo(z)
                                                                            pg.click(z)
                                                                            y = 0
                                                                        else:
                                                                            y += 1
                                                                if y < 6:
                                                                    pg.moveTo(x)
                                                                    pg.click(x)
                                                                    x = None
                                                                    z = None
                                                                    while x == None:
                                                                        x = pg.locateOnScreen(wayConcat14, grayscale=True, confidence=0.73)
                                                                        if x == None:
                                                                            z = pg.locateOnScreen(wayConcat13, grayscale=True, confidence=0.73)
                                                                            if z == None:
                                                                                z = pg.locateOnScreen(wayConcat12, grayscale=True, confidence=0.73)
                                                                            if z != None:
                                                                                pg.moveTo(z)
                                                                                pg.click(z)
                                                                    pg.moveTo(x)
                                                                    pg.click(x)
                                                                WithoutAd = 0
                                                            WithoutAd += 1
                                                    
                    if x != None:
                        print("Fechando anúncios agora...")
                        WithoutAd = 0
                        FirstAd = True
                        pg.click(x)
                    else:
                        #x = pg.locateOnScreen(wayConcat7, grayscale=True, confidence=0.85, region=(0,int(2*tela.height/3),int(0.4*tela.width/3)-1,int(tela.height/3)))
                        x = pg.locateOnScreen(r"C:\Users\user\Desktop\Felipe\Jupyter\PNGs\BattleIcon.png", grayscale=True, confidence=0.8)
                        if x != None and FirstAd == False:
                            pg.moveTo(x)
                            pg.click(x)
                            #FirstAd = True
                            x = None
            print("Anúncios fechados! Prosseguindo com carregamento...")
                    #print("Loop Interno: "+str(WithoutAd)+"     1° Ad clicado? "+str(FirstAd)+"     Click: "+str(x))

        if wayConcat0 != wayConcat5: #Hipótese do jogo aberto, fora dos anúncios e fora da arena
            print("Entrando na arena pelo menu de ações...")
            if wayConcat0 == wayConcat6: #Sub-hipótese do menu aberto sem clique
                way1 = r"\QuestsEntrance"
            elif wayConcat0 == wayConcat6b: #Sub-hipótese do menu aberto sem clique em Dragon City desatualizado
                way1 = r"\QuestsEntrance2"
            else: #Sub-hipótese do jogo fora do menu e fora da arena
                way1 = r"\BattleIcon"

            while way1 != r"ExitLoop":
                wayConcat1 = wayStart + way1 + wayEnd
                x = None
                while x == None:
                    x = pg.locateOnScreen(wayConcat1, grayscale=True, confidence=0.85)
                    if x == None and way1 == r"\QuestsEntrance":
                        x = pg.locateOnScreen(wayStart + r"\QuestsEntrance2" + wayEnd, grayscale=True, confidence=0.85)
                        if x != None:
                            QuestEntrance2 = pg.center(x)
                            xQuestEntrance2 = QuestEntrance2.x
                            yQuestEntrance2 = QuestEntrance2.y + x.height * 2.1
                            pg.moveTo(xQuestEntrance2,yQuestEntrance2)
                            pg.click(xQuestEntrance2,yQuestEntrance2)
                    elif x != None:
                        pg.moveTo(x)
                        pg.click(x)
                if way1 == r"\BattleIcon":
                    way1 = r"\QuestsEntrance"
                elif way1 == r"\QuestsEntrance":
                    way1 = r"ExitLoop"
        tm.sleep(1.5)
        x3 = pg.locateOnScreen(wayConcat5, grayscale=True, confidence=0.75)
    print("Arena reaberta com sucesso! Continuando o código default...")
#Imagem Trigger de flow (Step No. 1)
tm.sleep(5)
clickhold()
#tm.sleep(25)
#first loop click
x = 1
while x != None:
    conf = 0.9
    x = None
    while x == None:
        wayConcat1 = wayStart + r"\Quest1" + wayEnd
        x = pg.locateOnScreen(wayConcat1, grayscale=True, confidence=conf)
        if x == None:
            conf -= 0.01
    tm.sleep(0.05)
    pg.moveTo(x)
    pg.click(x)
    tm.sleep(0.2)
    x = pg.locateOnScreen(wayConcat1, grayscale=True, confidence=conf)

#Começo do Loop
#Começo do Loop
#Começo do Loop

verify = False
clickBreed = True
way1 = r"\GoToBattle"
#40
way2 = r"\Quest1"
fails = 0
fracassosSeguidos = 0
k = 0
x3 = None
way4 = None
conf = None
Regiao = None
step = 1
vezesSemReiniciar = 0

confWay1 = 0.86
confWay2 = 0.86
confWay3 = 0.86
confWay4 = 0.86
confWay5 = 0.86
confWay6 = 0.86
confWay7 = 0.86
confWay8 = 0.86
confWay9 = 0.86
confWay10 = 0.86
confWay11 = 0.86
confWay12 = 0.86
confWay13 = 0.86
confWay14 = 0.86
confWay15 = 0.86
confWay16 = 0.86

while InitialKillNumber < 501:
    if way1 != r"\Yes" and way1 != r"\SelectDragon":
        tm.sleep(0.25)
    x2 = None
    x3 = None
    wayConcat1 = wayStart + way1 + wayEnd
    if way2 != None:
        wayConcat2 = wayStart + way2 + wayEnd
    #if conf == None:
    #    conf = 0.89
    conf = 0.89
    initialTime = tm.localtime()[7]*86400+tm.localtime()[3]*3600+tm.localtime()[4]*60+tm.localtime()[5]
    while x2 == None and conf > 0.2: #and fails < 18:
        x2 = pg.locateOnScreen(wayConcat1, confidence=conf, grayscale=True, region=Regiao)
        #print(str(conf)+way1)
        if x2 == None:
            conf -= 0.005
            fails += 1
            if way2 != None:
                x3 = pg.locateOnScreen(wayConcat2, confidence=conf, grayscale=True, region=Regiao2)
                #print(str(conf)+way2)
            if x3 != None:
                pg.moveTo(x3)
                pg.click(x3)
                tm.sleep(0.5)
                x3 = None
                conf = 0.91
                fails = 0
            #else:
                #print("Att "+str(way2)+" failed")
        else:
            fails = 0
            pg.moveTo(x2)
            pg.click(x2)

    finalTime = tm.localtime()[7]*86400+tm.localtime()[3]*3600+tm.localtime()[4]*60+tm.localtime()[5]
    
    if finalTime-initialTime >= 3 and step == 3:
        firstAtk = "Opponent"
    elif finalTime-initialTime < 3 and step == 3:
        firstAtk = "Player"
    #print(firstAtk)
    
#120
    if x2 != None and fails < 18:
        wayConcat1 = wayStart + way1 + wayEnd
        tm.sleep(0.3)
        #print(way1+" in "+str(x2)+".    step"+str(step))
        x2 = pg.locateOnScreen(wayConcat1, grayscale=False, confidence=0.75)
        if x2 == None:
            fails = 0
            step += 1
            way2 = way1
            Regiao = [0,0,tela.width-1,tela.height-1]
            Regiao2 = [0,0,tela.width-1,tela.height-1]
            if step == 2:
                way1 = r"\GoToBattle2"
                way2 = None
                way3 = None
                way4 = None
                confWay1 = conf + 0.05
                conf = 0.91
            elif step == 3:
                way1 = r"\Quest7"
                way2 = None
                way3 = None
                way4 = None
                confWay2 = conf + 0.05
                conf = confWay3
                #mudei aqui, qualquer coisa volta ao 2.6
                tm.sleep(0.1)
            elif step == 4:
                way1 = r"\SelectDragon"
                way2 = r"\Quest7"
                way3 = None
                way4 = None
                Regiao = [int(tela.width*2/3),int(tela.height*2/3),int(tela.width*1/3)-1,int(tela.height*1/3)-1]
                Regiao2 = [0,0,tela.width-1,tela.height-1]
                confWay3 = conf + 0.05
                conf = confWay4
                tm.sleep(1.4)
                #Não diminuir esse, que já está na margem de erro adequada contando com a internet
#140
            elif step == 5:
                way1 = r"\Quest4"
                way2 = None
                way3 = None
                way4 = None
                confWay4 = conf + 0.05
                conf = confWay5
            elif step == 6:
                way1 = r"\PrintToSwitch"
                way2 = r"\Quest4"
                way3 = None
                way4 = None
                Regiao = [int(tela.width*0/3),int(tela.height*1/2),int(tela.width*1/1)-1,int(tela.height*9/20)-1]
                Regiao2 = [int(tela.width*0/3),int(tela.height*1/2),int(tela.width*1/1)-1,int(tela.height*9/20)-1]
                confWay5 = conf + 0.05
                conf = confWay6
                tm.sleep(0.2)
            elif step == 7:
                confWay13 = conf + 0.05
                step = 0
                #Iniciar checagem para certificar que o defeat já ocorreu:
                wayConcat1 = wayStart + r"\Quests" + wayEnd
                wayConcat2 = wayStart + r"\PrintToSwitch" + wayEnd
                x2 = None
                x2b = None
                conf = 0.91
                contador = 0
                while x2 == None:
                    x2 = pg.locateOnScreen(wayConcat1, confidence=conf, grayscale=True)
                    if x2 == None:
                        x2b = pg.locateOnScreen(wayConcat2, confidence=conf, grayscale=True, region=Regiao2)
                        if x2b != None:
                            pg.moveTo(x2b)
                            if contador < 4:
                                pg.click(x2b)
                            contador += 1
                            if contador >= 5:
                                lastPlace = None
                                for lugar in [r"\CloseBreed",r"\Yes"]:
                                    wayConcat2 = wayStart + lugar + wayEnd
                                    if lastPlace != None:
                                        wayConcat3 = wayStart + lastPlace + wayEnd
                                    x2b = None
                                    while x2b == None:
                                        x2b = pg.locateOnScreen(wayConcat2, confidence=conf, grayscale=True)
                                        if x2b == None and lastPlace != None:
                                            x2c = pg.locateOnScreen(wayConcat3, confidence=conf, grayscale=True)
                                            if x2c != None:
                                                pg.moveTo(x2c)
                                                pg.click(x2c)
                                    lastPlace = lugar
                                    pg.moveTo(x2b)
                                    pg.click(x2b)
                                InitialKillNumber -= 1
                            conf = 0.91
                            tm.sleep(2.9)
                        else:
                            conf -= 0.01
                InitialKillNumber += 1
                if vezesSemReiniciar <= 51:
                    vezesSemReiniciar += 1
                    tm.sleep(0.3)
                else:
                    vezesSemReiniciar = 0
                    tm.sleep(7)
                    pg.hotkey('alt','f4')
                    tm.sleep(0.5)
                    returnerToGame(2)
                sucessos += 1
                fracassosSeguidos = 0
                print("sucessos: "+str(sucessos)+" de "+str(int(sucessos)+int(fracassos))+"\nkills: "+str(InitialKillNumber)+" / 500"+", registrado às "+str(tm.localtime()[3])+":"+str(tm.localtime()[4])+":"+str(tm.localtime()[5]))
                clickhold()
                way1 = r"\Quest1"
                way2 = None
                way3 = None
                conf = 0.91
                way4 = None
                tm.sleep(0.5)
#return to first loop click
            elif step == 1:
                way1 = r"\GoToBattle"
                clickBreed = True
                confWay0 = conf + 0.05
                conf = confWay1
        else:
            fails += 1
#180
    else:
        if fails < 18:
            fails += 1
    #print(str(fails)+str(way1))
    if fails >= 18:
        way1 = r"\CloseBreed"
        #way3 = r"\Yes"
        fracassos += 1
        fracassosSeguidos += 1
        print("sucessos: "+str(sucessos)+" de "+str(int(sucessos)+int(fracassos)))
        #print(str(way1)+"    "+str(way2)+"     "+str(way3))
        way1 = r"\Quests1"
        clickhold()
        verificador = "fracasso"
        fails = 0
        tm.sleep(0.31)
    if fracassosSeguidos > 12:
        fracassosSeguidos = 0
        returnerToGame(1)
        
#PrintToSwitch
# Out:
# sucessos: 1 de 1
# kills: 1 / 500, registrado às 0:20:1
# sucessos: 2 de 2
# kills: 2 / 500, registrado às 0:20:48
# sucessos: 3 de 3
# kills: 3 / 500, registrado às 0:21:36
# sucessos: 4 de 4
# kills: 4 / 500, registrado às 0:22:23
# sucessos: 5 de 5
# kills: 5 / 500, registrado às 0:23:11
# sucessos: 6 de 6
# kills: 6 / 500, registrado às 0:23:58
# sucessos: 7 de 7
# kills: 7 / 500, registrado às 0:24:45
# sucessos: 8 de 8
# kills: 8 / 500, registrado às 0:25:33
# sucessos: 9 de 9
# kills: 9 / 500, registrado às 0:26:21
# sucessos: 10 de 10
# kills: 10 / 500, registrado às 0:27:8
# sucessos: 11 de 11
# kills: 11 / 500, registrado às 0:27:55
# sucessos: 12 de 12
# kills: 12 / 500, registrado às 0:28:42
# sucessos: 13 de 13
# kills: 13 / 500, registrado às 0:29:30
# sucessos: 14 de 14
# kills: 14 / 500, registrado às 0:30:17
# sucessos: 15 de 15
# kills: 15 / 500, registrado às 0:31:4
# sucessos: 16 de 16
# kills: 16 / 500, registrado às 0:31:52
# sucessos: 17 de 17
# kills: 17 / 500, registrado às 0:32:40
# sucessos: 18 de 18
# kills: 18 / 500, registrado às 0:33:23
# sucessos: 19 de 19
# kills: 19 / 500, registrado às 0:34:10
# sucessos: 20 de 20
# kills: 20 / 500, registrado às 0:34:58
# sucessos: 21 de 21
# kills: 21 / 500, registrado às 0:35:45
# sucessos: 22 de 22
# kills: 22 / 500, registrado às 0:36:33
# sucessos: 23 de 23
# kills: 23 / 500, registrado às 0:37:20
# sucessos: 24 de 24
# kills: 24 / 500, registrado às 0:38:7
# sucessos: 25 de 25
# kills: 25 / 500, registrado às 0:38:55
# sucessos: 26 de 26
# kills: 26 / 500, registrado às 0:39:42
# sucessos: 27 de 27
# kills: 27 / 500, registrado às 0:40:30
# sucessos: 28 de 28
# kills: 28 / 500, registrado às 0:41:17
# sucessos: 29 de 29
# kills: 29 / 500, registrado às 0:42:5
# sucessos: 30 de 30
# kills: 30 / 500, registrado às 0:42:52
# sucessos: 31 de 31
# kills: 31 / 500, registrado às 0:43:40
# sucessos: 32 de 32
# kills: 32 / 500, registrado às 0:44:28
# sucessos: 33 de 33
# kills: 33 / 500, registrado às 0:45:15
# sucessos: 34 de 34
# kills: 34 / 500, registrado às 0:46:3
# sucessos: 35 de 35
# kills: 35 / 500, registrado às 0:46:50
# sucessos: 36 de 36
# kills: 36 / 500, registrado às 0:47:37
# sucessos: 37 de 37
# kills: 37 / 500, registrado às 0:48:25
# sucessos: 38 de 38
# kills: 38 / 500, registrado às 0:49:12
# sucessos: 39 de 39
# kills: 39 / 500, registrado às 0:50:0
# sucessos: 40 de 40
# kills: 40 / 500, registrado às 0:50:47
# sucessos: 41 de 41
# kills: 41 / 500, registrado às 0:51:34
# sucessos: 42 de 42
# kills: 42 / 500, registrado às 0:52:22
# sucessos: 43 de 43
# kills: 43 / 500, registrado às 0:53:9
# sucessos: 44 de 44
# kills: 44 / 500, registrado às 0:53:58
# sucessos: 45 de 45
# kills: 45 / 500, registrado às 0:54:45
# sucessos: 46 de 46
# kills: 46 / 500, registrado às 0:55:32
# sucessos: 47 de 47
# kills: 47 / 500, registrado às 0:56:20
# sucessos: 48 de 48
# kills: 48 / 500, registrado às 0:57:7
# sucessos: 49 de 49
# kills: 49 / 500, registrado às 0:57:50
# sucessos: 50 de 50
# kills: 50 / 500, registrado às 0:58:37
# sucessos: 51 de 51
# kills: 51 / 500, registrado às 0:59:25
# sucessos: 52 de 52
# kills: 52 / 500, registrado às 1:0:12
# Janela de jogo não encontrada. Reabrindo Dragon City...
# Reabrindo jogo...
# Aguardando carregamento...
# Fechando anúncios obstrutores...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 336>()
#     484     pg.hotkey('alt','f4')
#     485     tm.sleep(0.5)
# --> 486     returnerToGame(2)
#     487 sucessos += 1
#     488 fracassosSeguidos = 0
#
# Input In [8], in returnerToGame(Version)
#     182 x = pg.locateOnScreen(wayConcat10, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
#     183 if x == None:
# --> 184     x = pg.locateOnScreen(wayConcat11, grayscale=True, confidence=0.98, region=(int(0.761*tela.width),int(0.048*tela.height),int(0.122*tela.width)-1,int(0.199*tela.height)-1))
#     185     if x == None:
#     186         x = pg.locateOnScreen(wayConcat14, grayscale=True, confidence=0.92, region=(int(2*tela.width/3),0,int(1*tela.width/3)-1,int(tela.height/2.4)-1))
#
# File C:\Program Files\Python\lib\site-packages\pyautogui\__init__.py:175, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     172 @functools.wraps(wrappedFunction)
#     173 def wrapper(*args, **kwargs):
#     174     try:
# --> 175         return wrappedFunction(*args, **kwargs)
#     176     except pyscreeze.ImageNotFoundException:
#     177         raise ImageNotFoundException
#
# File C:\Program Files\Python\lib\site-packages\pyautogui\__init__.py:213, in locateOnScreen(*args, **kwargs)
#     211 @raisePyAutoGUIImageNotFoundException
#     212 def locateOnScreen(*args, **kwargs):
# --> 213     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyscreeze\__init__.py:372, in locateOnScreen(image, minSearchTime, **kwargs)
#     370 while True:
#     371     try:
# --> 372         screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
#     373         retVal = locate(image, screenshotIm, **kwargs)
#     374         try:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyscreeze\__init__.py:145, in requiresPillow.<locals>.wrapper(*args, **kwargs)
#     143 if _PILLOW_UNAVAILABLE:
#     144     raise PyScreezeException('The Pillow package is required to use this function.')
# --> 145 return wrappedFunction(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyscreeze\__init__.py:457, in _screenshot_win32(imageFilename, region)
#     452 """
#     453 TODO
#     454 """
#     455 # TODO - Use the winapi to get a screenshot, and compare performance with ImageGrab.grab()
#     456 # https://stackoverflow.com/a/3586280/1893164
# --> 457 im = ImageGrab.grab()
#     458 if region is not None:
#     459     assert len(region) == 4, 'region argument must be a tuple of four ints'
#
# File C:\Program Files\Python\lib\site-packages\PIL\ImageGrab.py:46, in grab(bbox, include_layered_windows, all_screens, xdisplay)
#      42 elif sys.platform == "win32":
#      43     offset, size, data = Image.core.grabscreen_win32(
#      44         include_layered_windows, all_screens
#      45     )
# ---> 46     im = Image.frombytes(
#      47         "RGB",
#      48         size,
#      49         data,
#      50         # RGB, 32-bit line padding, origin lower left corner
#      51         "raw",
#      52         "BGR",
#      53         (size[0] * 3 + 3) & -4,
#      54         -1,
#      55     )
#      56     if bbox:
#      57         x0, y0 = offset
#
# File C:\Program Files\Python\lib\site-packages\PIL\Image.py:2706, in frombytes(mode, size, data, decoder_name, *args)
#    2703 if decoder_name == "raw" and args == ():
#    2704     args = mode
# -> 2706 im = new(mode, size)
#    2707 im.frombytes(data, decoder_name, args)
#    2708 return im
#
# File C:\Program Files\Python\lib\site-packages\PIL\Image.py:2670, in new(mode, size, color)
#    2668     im.palette = ImagePalette.ImagePalette()
#    2669     color = im.palette.getcolor(color)
# -> 2670 return im._new(core.fill(mode, size, color))
#
# KeyboardInterrupt:
